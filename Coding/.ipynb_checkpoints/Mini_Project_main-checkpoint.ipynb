# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# 1. Importing the required packages for the project

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import keras
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
from keras.models import Sequential
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import load_img,img_to_array
from keras.preprocessing import image
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2. Loading and Preprocessing the data

# %%
#preparation of data
import os
X=[]
Y=[]
path = "/content/drive/MyDrive/Colab Notebooks/dataset/covid"
for image in os.listdir(path):
  img_path = os.path.join(path,image)
  img = load_img(img_path,target_size=(224,224))
  img = img_to_array(img)
  X.append(img)
  Y.append(1)
path = "/content/drive/MyDrive/Colab Notebooks/dataset/normal"
for image in os.listdir(path):
  img_path = os.path.join(path,image)
  img = load_img(img_path,target_size=(224,224))
  img = img_to_array(img)
  X.append(img)
  Y.append(0)
X = np.array(X)
Y = np.array(Y)
print(X.shape)
print(Y.shape)
# Out:
# (392, 224, 224, 3)
# (392,)

# %% [markdown]
# 3. Splitting the data into train and test

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.20,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (313, 224, 224, 3)
# (79, 224, 224, 3)
# (313,)
# (79,)

# %% [markdown]
# 4. Data Preprocessing and Data Augmentation

# %%
train_datagen = image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

test_datagen = image.ImageDataGenerator(rescale=1./255)

# %% [markdown]
# 5. Creating Train and Test Generator

# %%
train_generator = train_datagen.flow(
    X_train,
    y=Y_train,
    batch_size=32,
    shuffle=True
)

# %%
test_generator = test_datagen.flow(
    X_test,
    y=Y_test,
    batch_size=32,
    shuffle=True
)

# %% [markdown]
# 6. Creating Model

# %%
#model creation
model = Sequential()
model.add(Conv2D(32,kernel_size= (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss=keras.losses.binary_crossentropy,optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 64)      18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                5537856
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,668,097
# Trainable params: 5,668,097
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 7. Plotting CNN Model

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# 8. Model fit generation and evaluation

# %%
out = model.fit_generator(train_generator,steps_per_epoch=8,epochs=10,validation_data=test_generator,validation_steps=2)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 3s 351ms/step - loss: 0.1053 - accuracy: 0.9558 - val_loss: 0.1748 - val_accuracy: 0.9531
# Epoch 2/10
# 8/8 [==============================] - 3s 345ms/step - loss: 0.2678 - accuracy: 0.9157 - val_loss: 0.1981 - val_accuracy: 0.9531
# Epoch 3/10
# 8/8 [==============================] - 3s 358ms/step - loss: 0.1681 - accuracy: 0.9478 - val_loss: 0.2186 - val_accuracy: 0.9375
# Epoch 4/10
# 8/8 [==============================] - 3s 344ms/step - loss: 0.1574 - accuracy: 0.9398 - val_loss: 0.0899 - val_accuracy: 0.9688
# Epoch 5/10
# 8/8 [==============================] - 3s 343ms/step - loss: 0.1473 - accuracy: 0.9558 - val_loss: 0.1100 - val_accuracy: 0.9688
# Epoch 6/10
# 8/8 [==============================] - 3s 342ms/step - loss: 0.1049 - accuracy: 0.9639 - val_loss: 0.0759 - val_accuracy: 1.0000
# Epoch 7/10
# 8/8 [==============================] - 3s 351ms/step - loss: 0.0921 - accuracy: 0.9727 - val_loss: 0.1741 - val_accuracy: 0.9531
# Epoch 8/10
# 8/8 [==============================] - 3s 352ms/step - loss: 0.1121 - accuracy: 0.9727 - val_loss: 0.0942 - val_accuracy: 0.9688
# Epoch 9/10
# 8/8 [==============================] - 3s 340ms/step - loss: 0.1486 - accuracy: 0.9558 - val_loss: 0.0568 - val_accuracy: 0.9844
# Epoch 10/10
# 8/8 [==============================] - 3s 345ms/step - loss: 0.1481 - accuracy: 0.9679 - val_loss: 0.1383 - val_accuracy: 0.9688

# %%
y_pred = model.predict_classes(X_test)

# %%
model.save("model_1.h5")

# %%
model.evaluate_generator(train_generator)
# Out:
# [0.1412699669599533, 0.9776358008384705]

# %%
model.evaluate_generator(test_generator)
# Out:
# [0.15832053124904633, 0.9620253443717957]

# %% [markdown]
# 9. Plotting Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
cm = confusion_matrix(Y_test, y_pred)

cm
# Out:
# array([[27,  1],
#        [ 0, 51]])

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        28
#            1       0.98      1.00      0.99        51
#
#     accuracy                           0.99        79
#    macro avg       0.99      0.98      0.99        79
# weighted avg       0.99      0.99      0.99        79

# %%
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(Y_test, y_pred)
# Out:
# 0.9724925491960122

# %% [markdown]
# 10. Plotting training and validation loss

# %%
loss = out.history['loss']
val_loss = out.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, color='red', label='Training loss')
plt.plot(epochs, val_loss, color='green', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = out.history['accuracy']
val_acc = out.history['val_accuracy']
plt.plot(epochs, acc, color='red', label='Training acc')
plt.plot(epochs, val_acc, color='green', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# 11. Plotting Confusion Matrix heatmap

# %%
sns.heatmap(cm,annot=True)

# %% [markdown]
# Testing out other models without data augmentation and dropout layers

# %%
non_aug_out = model.fit(X_train,Y_train,epochs=10,validation_steps=2,steps_per_epoch=8)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 6s 458ms/step - loss: 31.1076 - accuracy: 0.8403
# Epoch 2/10
# 8/8 [==============================] - 1s 133ms/step - loss: 1.1410 - accuracy: 0.7636
# Epoch 3/10
# 8/8 [==============================] - 1s 132ms/step - loss: 0.5188 - accuracy: 0.7796
# Epoch 4/10
# 8/8 [==============================] - 1s 132ms/step - loss: 0.4898 - accuracy: 0.7955
# Epoch 5/10
# 8/8 [==============================] - 1s 132ms/step - loss: 0.2875 - accuracy: 0.9105
# Epoch 6/10
# 8/8 [==============================] - 1s 132ms/step - loss: 0.2801 - accuracy: 0.8946
# Epoch 7/10
# 8/8 [==============================] - 1s 133ms/step - loss: 0.4257 - accuracy: 0.9042
# Epoch 8/10
# 8/8 [==============================] - 1s 133ms/step - loss: 0.2927 - accuracy: 0.9233
# Epoch 9/10
# 8/8 [==============================] - 1s 133ms/step - loss: 0.2655 - accuracy: 0.9137
# Epoch 10/10
# 8/8 [==============================] - 1s 132ms/step - loss: 0.1990 - accuracy: 0.9329

# %%
model_new = Sequential()
model_new.add(Conv2D(32,kernel_size= (3, 3), activation='relu', input_shape=(224, 224, 3)))
model_new.add(Conv2D(64, (3, 3), activation='relu'))
model_new.add(MaxPooling2D((2, 2)))


model_new.add(Conv2D(64, (3, 3), activation='relu'))
model_new.add(MaxPooling2D((2, 2)))


model_new.add(Conv2D(128, (3, 3), activation='relu'))
model_new.add(MaxPooling2D((2, 2)))


model_new.add(Flatten())
model_new.add(Dense(64, activation='relu'))

model_new.add(Dense(1, activation='sigmoid'))


model_new.compile(loss=keras.losses.binary_crossentropy,optimizer='adam',metrics=['accuracy'])

# %%
out1 = model_new.fit_generator(train_generator,steps_per_epoch=8,epochs=10,validation_data=test_generator,validation_steps=2)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 3s 378ms/step - loss: 1.6292 - accuracy: 0.4665 - val_loss: 0.5762 - val_accuracy: 0.9375
# Epoch 2/10
# 8/8 [==============================] - 3s 337ms/step - loss: 0.5504 - accuracy: 0.7737 - val_loss: 0.3430 - val_accuracy: 0.9062
# Epoch 3/10
# 8/8 [==============================] - 3s 349ms/step - loss: 0.2973 - accuracy: 0.8948 - val_loss: 0.2515 - val_accuracy: 0.9219
# Epoch 4/10
# 8/8 [==============================] - 3s 341ms/step - loss: 0.2397 - accuracy: 0.8834 - val_loss: 0.3967 - val_accuracy: 0.8438
# Epoch 5/10
# 8/8 [==============================] - 3s 339ms/step - loss: 0.3097 - accuracy: 0.8893 - val_loss: 0.2406 - val_accuracy: 0.9062
# Epoch 6/10
# 8/8 [==============================] - 3s 339ms/step - loss: 0.1079 - accuracy: 0.9775 - val_loss: 0.1573 - val_accuracy: 0.9531
# Epoch 7/10
# 8/8 [==============================] - 3s 339ms/step - loss: 0.1360 - accuracy: 0.9493 - val_loss: 0.0676 - val_accuracy: 0.9844
# Epoch 8/10
# 8/8 [==============================] - 3s 338ms/step - loss: 0.0522 - accuracy: 0.9933 - val_loss: 0.1163 - val_accuracy: 0.9688
# Epoch 9/10
# 8/8 [==============================] - 3s 353ms/step - loss: 0.0536 - accuracy: 0.9904 - val_loss: 0.6048 - val_accuracy: 0.7969
# Epoch 10/10
# 8/8 [==============================] - 3s 337ms/step - loss: 0.1866 - accuracy: 0.9167 - val_loss: 0.1320 - val_accuracy: 0.9688

# %%
x = ["With DA and DO","Without DA","Without DO"]

energy = [out.history['accuracy'][-1], non_aug_out.history['accuracy'][-1], out1.history['accuracy'][-1]]
variance =[out.history['loss'][-1], non_aug_out.history['loss'][-1], out1.history['loss'][-1]]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, energy, color='green', yerr=variance)
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Accuracy from various models")

plt.xticks(x_pos, x)

plt.show()

print("DA -- Data Augmentation\nDO -- Dropout Layers")
# Out:
# DA -- Data Augmentation
# DO -- Dropout Layers
